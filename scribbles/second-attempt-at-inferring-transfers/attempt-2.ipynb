# %% [markdown]
# Let's aim for cleaner code

# %%
import geopandas
import pandas as pd
import numpy as np
import os
import re

# %%
airports = pd.read_csv("/Users/JO/PhD/hemspy/data/helipad-data/raw-data/helipad-coordinates.csv", sep=";")
airports_gdf = geopandas.GeoDataFrame(airports, geometry=geopandas.points_from_xy(airports.longitude, airports.latitude), crs="EPSG:4326")
airports_gdf = airports_gdf.to_crs("EPSG:32634") #to metric coords
airports_gdf.geometry = airports_gdf.geometry.buffer(distance=airports.radius)
airports_gdf = airports_gdf.to_crs("EPSG:4326") #back to conventional

# %%
flights_path = '/Users/JO/PhD/hemspy/data/fr24-data/raw-data-unzipped-rearranged/flights'
flights_files = [f for f in os.listdir(flights_path) if f.endswith('.csv')]

flights_df_list, positions_df_list = [], []
for file in flights_files:
    flights_df_list.append(pd.read_csv(flights_path+'/'+file))

flights_df = pd.concat(flights_df_list, ignore_index=True)

flights_df['flight_id'] = flights_df['flight_id'].astype(int)

positions_path = '/Users/JO/PhD/hemspy/data/fr24-data/raw-data-unzipped-rearranged/positions'
positions_files = [os.path.join(positions_path, file) for file in os.listdir(positions_path) if file.endswith('.csv')]

# List to store DataFrames
positions_df_list = []

regex_pattern = r'_(.*?)\.'
regex = re.compile(regex_pattern)

# Iterate over each file
for file in positions_files:
    # Extract the flight_id from the file name
    flight_id_match = regex.search(os.path.basename(file))
    if flight_id_match:
        flight_id = flight_id_match.group(1)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file, usecols=['snapshot_id', 'altitude', 'latitude', 'longitude', 'speed'])
        
        # Add a column for flight_id
        df['flight_id'] = flight_id
        
        # Append the DataFrame to the list
        positions_df_list.append(df)

# Combine all DataFrames into a single DataFrame
positions_df = pd.concat(positions_df_list, ignore_index=True)

positions_df['flight_id'] = positions_df['flight_id'].astype(int)

d = pd.merge(positions_df, flights_df, on='flight_id', how='left')

d['UTC'] = pd.to_datetime(d['snapshot_id'], unit='s', utc=True)
d['date'] = d['UTC'].dt.date
d['year'] = d['UTC'].dt.year

# Limit to UAS and OSD to make data smaller
d = d[d['reg'].isin(['SEJSK', 'SEJSI'])]
d = geopandas.GeoDataFrame(d, geometry=geopandas.points_from_xy(d.longitude, d.latitude), crs="EPSG:4326")
d = geopandas.sjoin(d, airports_gdf, how="left", predicate="within")

# %%
d.drop(['index_right', 'equip', 'icao', 'is_primary_helipad', 'helipad_location', 'year', 'date', 'is_primary_hospital', 'ambulance_meetup', 'latitude_right', 'reserved', 'flight', 'callsign', 'longitude_right', 'radius', 'real_to', 'schd_from', 'schd_to'], axis=1, inplace=True)

# %%
d = d.groupby('aircraft_id').apply(lambda x: x.sort_values('UTC'), include_groups=False)

# %%
d.reset_index(drop=True, inplace=True)

# %%
d
# Out:
#          snapshot_id  altitude  latitude_left  longitude_left  speed  \
# 0         1517660632       725       55.55214        13.37061     73
# 1         1517660641       850       55.55391        13.36633     77
# 2         1517660650       900       55.55549        13.36066     85
# 3         1517660656       925       55.55644        13.35713     89
# 4         1517660662      1025       55.55759        13.35322     85
# ...              ...       ...            ...             ...    ...
# 2764173   1715776157         0       59.89304        17.60881     26
# 2764174   1715776160         0       59.89290        17.60824     24
# 2764175   1715776164         0       59.89275        17.60770     18
# 2764176   1715776169         0       59.89262        17.60739      9
# 2764177   1715776238         0       59.90305        17.60074      0
#
#          flight_id    reg                       UTC  \
# 0        273769871  SEJSI 2018-02-03 12:23:52+00:00
# 1        273769871  SEJSI 2018-02-03 12:24:01+00:00
# 2        273769871  SEJSI 2018-02-03 12:24:10+00:00
# 3        273769871  SEJSI 2018-02-03 12:24:16+00:00
# 4        273769871  SEJSI 2018-02-03 12:24:22+00:00
# ...            ...    ...                       ...
# 2764173  893015657  SEJSK 2024-05-15 12:29:17+00:00
# 2764174  893015657  SEJSK 2024-05-15 12:29:20+00:00
# 2764175  893015657  SEJSK 2024-05-15 12:29:24+00:00
# 2764176  893015657  SEJSK 2024-05-15 12:29:29+00:00
# 2764177  893015657  SEJSK 2024-05-15 12:30:38+00:00
#
#                           geometry         hospital_name       zone_name
# 0        POINT (13.37061 55.55214)                   NaN             NaN
# 1        POINT (13.36633 55.55391)                   NaN             NaN
# 2        POINT (13.36066 55.55549)                   NaN             NaN
# 3        POINT (13.35713 55.55644)                   NaN             NaN
# 4        POINT (13.35322 55.55759)                   NaN             NaN
# ...                            ...                   ...             ...
# 2764173  POINT (17.60881 59.89304)  Akademiska sjukhuset  Ärna flygplats
# 2764174  POINT (17.60824 59.89290)  Akademiska sjukhuset  Ärna flygplats
# 2764175  POINT (17.60770 59.89275)  Akademiska sjukhuset  Ärna flygplats
# 2764176  POINT (17.60739 59.89262)  Akademiska sjukhuset  Ärna flygplats
# 2764177  POINT (17.60074 59.90305)  Akademiska sjukhuset  Ärna flygplats
#
# [2764178 rows x 11 columns]

# %%
# Identify transitions into and out of helipad zones
d['in_helipad_zone'] = ~d['zone_name'].isna()
d['zone_change'] = d['in_helipad_zone'].ne(d['in_helipad_zone'].shift())

# %%
# Extract the entry and exit times
d['entry'] = (d['zone_change'] == True) & (d['in_helipad_zone'] == True)
d['exit'] = (d['zone_change'] == True) & (d['in_helipad_zone'] == False)
d['UTC_str'] = d['UTC'].astype(str)

# %%
entries_and_exits = d[d['entry'] | d['exit']]

# %%
check_flight = np.random.choice(d.flight_id)
entries_and_exits.query(f"flight_id == {check_flight}")
# Out:
#          snapshot_id  altitude  latitude_left  longitude_left  speed  \
# 2033162   1653737611       900       59.90188        17.62482     99
#
#          flight_id    reg                       UTC  \
# 2033162  738656585  SEJSK 2022-05-28 11:33:31+00:00
#
#                           geometry         hospital_name       zone_name  \
# 2033162  POINT (17.62482 59.90188)  Akademiska sjukhuset  Ärna flygplats
#
#          in_helipad_zone  zone_change  entry   exit                    UTC_str
# 2033162             True         True   True  False  2022-05-28 11:33:31+00:00

# %%
m=airports_gdf.explore()
d[['geometry', 'flight_id', 'UTC_str']].query(f"flight_id == {check_flight}").explore(m=m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4094a04a4968ce00069f54c7b476fa81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4094a04a4968ce00069f54c7b476fa81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4094a04a4968ce00069f54c7b476fa81 = L.map(
#                 &quot;map_4094a04a4968ce00069f54c7b476fa81&quot;,
#                 {
#                     center: [61.42540989954378, 17.518324307296243],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4094a04a4968ce00069f54c7b476fa81);
#
#
#
#
#
#             var tile_layer_ec7375c9a90b9007a17dd3c1e835f7b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ec7375c9a90b9007a17dd3c1e835f7b0.addTo(map_4094a04a4968ce00069f54c7b476fa81);
#
#
#             map_4094a04a4968ce00069f54c7b476fa81.fitBounds(
#                 [[55.70286361361216, 11.841525845274306], [67.14795618547541, 23.19512276931818]],
#                 {}
#             );
#
#
#         function geo_json_3e369738a545d21be052753366bcb281_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3e369738a545d21be052753366bcb281_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3e369738a545d21be052753366bcb281_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3e369738a545d21be052753366bcb281_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3e369738a545d21be052753366bcb281_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3e369738a545d21be052753366bcb281.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3e369738a545d21be052753366bcb281_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3e369738a545d21be052753366bcb281 = L.geoJson(null, {
#                 onEachFeature: geo_json_3e369738a545d21be052753366bcb281_onEachFeature,
#
#                 style: geo_json_3e369738a545d21be052753366bcb281_styler,
#                 pointToLayer: geo_json_3e369738a545d21be052753366bcb281_pointToLayer,
#         });
#
#         function geo_json_3e369738a545d21be052753366bcb281_add (data) {
#             geo_json_3e369738a545d21be052753366bcb281
#                 .addData(data);
#         }
#             geo_json_3e369738a545d21be052753366bcb281_add({&quot;bbox&quot;: [11.841525845274306, 55.70286361361216, 23.19512276931818, 67.14795618547541], &quot;features&quot;: [{&quot;bbox&quot;: [17.622427294373324, 59.838356229161604, 17.658063938189187, 59.856287166941975], &

# %%
d[['geometry', 'flight_id', 'UTC_str']].query(f"flight_id == {check_flight}").iloc[-2:].explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d62a608dfe095c97cb8f33677cc6971 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d62a608dfe095c97cb8f33677cc6971&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d62a608dfe095c97cb8f33677cc6971 = L.map(
#                 &quot;map_1d62a608dfe095c97cb8f33677cc6971&quot;,
#                 {
#                     center: [59.38266, 13.470515],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1d62a608dfe095c97cb8f33677cc6971);
#
#
#
#
#
#             var tile_layer_aa97b009f13c29de72e16b51fb33db24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aa97b009f13c29de72e16b51fb33db24.addTo(map_1d62a608dfe095c97cb8f33677cc6971);
#
#
#             map_1d62a608dfe095c97cb8f33677cc6971.fitBounds(
#                 [[59.37649, 13.46488], [59.38883, 13.47615]],
#                 {}
#             );
#
#
#         function geo_json_d307390398ba273b8a28a10d6b645048_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d307390398ba273b8a28a10d6b645048_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d307390398ba273b8a28a10d6b645048_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d307390398ba273b8a28a10d6b645048_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d307390398ba273b8a28a10d6b645048_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_d307390398ba273b8a28a10d6b645048.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d307390398ba273b8a28a10d6b645048_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d307390398ba273b8a28a10d6b645048 = L.geoJson(null, {
#                 onEachFeature: geo_json_d307390398ba273b8a28a10d6b645048_onEachFeature,
#
#                 style: geo_json_d307390398ba273b8a28a10d6b645048_styler,
#                 pointToLayer: geo_json_d307390398ba273b8a28a10d6b645048_pointToLayer,
#         });
#
#         function geo_json_d307390398ba273b8a28a10d6b645048_add (data) {
#             geo_json_d307390398ba273b8a28a10d6b645048
#                 .addData(data);
#         }
#             geo_json_d307390398ba273b8a28a10d6b645048_add({&quot;bbox&quot;: [13.46488, 59.37649, 13.47615, 59.38883], &quot;features&quot;: [{&quot;bbox&quot;: [13.47615, 59.37649, 13.47615, 59.37649], &quot;geometry&quot;: {&quot;coordinates&quot;: [13.47615, 59.37649], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2762515&quot;, &quot;properties&quot;: {&quot;UTC_str&quot;: &quot;2024-05-14 10:50:15+00:00&quot;, &quot;flight_id&quot;: 892760072}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [13.46488, 59.38883, 13.46488, 59.38883], &quot;geometry&quot;: {&quot;coordinates&quot;: [13.46488, 59.38883], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;2762516&quot;, &quot;properties&quot;: {&quot;UTC_str&quot;: &quot;2024-05-14 10:50:17+00:00&quot;, &quot;flight_id&quot;: 892760072}, &quot;type&quot;: &quot;Feature&quot;}], &qu

# %% [markdown]
# the stuff of nightmares

# %% [markdown]
# ### Testing hidden markov models

# %%
# calc ROC
def ROC(x):
    # Calculate distance
    point1 = x.geometry.to_crs("EPSG:32634")
    point2 = x.shift().geometry.to_crs("EPSG:32634")
    distance = point1.distance(point2)
    # Calculate change in altitude
    alt1 = x.altitude
    alt2 = x.shift().altitude
    alt_change = alt1 - alt2
    # Calculate rate of climb
    return alt_change / distance

def DELTA_SPEED(x):
     # Calculate distance
    point1 = x.geometry.to_crs("EPSG:32634")
    point2 = x.shift().geometry.to_crs("EPSG:32634")
    time = x.snapshot_id - x.shift().snapshot_id

    speed1 = x.speed
    speed2 = x.shift().speed
    return (speed1 - speed2) / time

def ASC(x):
    alt1 = x.altitude
    alt2 = x.shift().altitude
    return alt1 > alt2

# %%
distances = d.groupby('flight_id').apply(lambda x: ROC(x), include_groups=False)
d_speed = d.groupby('flight_id').apply(lambda x: DELTA_SPEED(x), include_groups=False)
ascent = d.groupby('flight_id').apply(lambda x: ASC(x), include_groups=False)
ROC = distances.reset_index(drop=True)
D_SPEED = d_speed.reset_index(drop=True)
ASC = ascent.reset_index(drop=True)

# %%
d['ROC'] = ROC
d['dSpeed'] = D_SPEED
d['ASC'] = ASC

# %%
d['ROC'] = np.where(d.ROC ==  np.inf, 0, d.ROC)
d['ROC'] = np.where(d.ROC ==  -np.inf, 0, d.ROC)
d['ROC'] = d['ROC'].fillna(0)

# %%
d['dSpeed'] = d['dSpeed'].fillna(0)
d['ASC'] = d['ASC'].fillna(0)

# %%
d
# Out:
#          snapshot_id  altitude  latitude_left  longitude_left  speed  \
# 0         1517660632       725       55.55214        13.37061     73
# 1         1517660641       850       55.55391        13.36633     77
# 2         1517660650       900       55.55549        13.36066     85
# 3         1517660656       925       55.55644        13.35713     89
# 4         1517660662      1025       55.55759        13.35322     85
# ...              ...       ...            ...             ...    ...
# 2764173   1715776157         0       59.89304        17.60881     26
# 2764174   1715776160         0       59.89290        17.60824     24
# 2764175   1715776164         0       59.89275        17.60770     18
# 2764176   1715776169         0       59.89262        17.60739      9
# 2764177   1715776238         0       59.90305        17.60074      0
#
#          flight_id    reg                       UTC  \
# 0        273769871  SEJSI 2018-02-03 12:23:52+00:00
# 1        273769871  SEJSI 2018-02-03 12:24:01+00:00
# 2        273769871  SEJSI 2018-02-03 12:24:10+00:00
# 3        273769871  SEJSI 2018-02-03 12:24:16+00:00
# 4        273769871  SEJSI 2018-02-03 12:24:22+00:00
# ...            ...    ...                       ...
# 2764173  893015657  SEJSK 2024-05-15 12:29:17+00:00
# 2764174  893015657  SEJSK 2024-05-15 12:29:20+00:00
# 2764175  893015657  SEJSK 2024-05-15 12:29:24+00:00
# 2764176  893015657  SEJSK 2024-05-15 12:29:29+00:00
# 2764177  893015657  SEJSK 2024-05-15 12:30:38+00:00
#
#                           geometry         hospital_name       zone_name  \
# 0        POINT (13.37061 55.55214)                   NaN             NaN
# 1        POINT (13.36633 55.55391)                   NaN             NaN
# 2        POINT (13.36066 55.55549)                   NaN             NaN
# 3        POINT (13.35713 55.55644)                   NaN             NaN
# 4        POINT (13.35322 55.55759)                   NaN             NaN
# ...                            ...                   ...             ...
# 2764173  POINT (17.60881 59.89304)  Akademiska sjukhuset  Ärna flygplats
# 2764174  POINT (17.60824 59.89290)  Akademiska sjukhuset  Ärna flygplats
# 2764175  POINT (17.60770 59.89275)  Akademiska sjukhuset  Ärna flygplats
# 2764176  POINT (17.60739 59.89262)  Akademiska sjukhuset  Ärna flygplats
# 2764177  POINT (17.60074 59.90305)  Akademiska sjukhuset  Ärna flygplats
#
#          in_helipad_zone  zone_change  entry   exit  \
# 0                  False         True  False   True
# 1                  False        False  False  False
# 2                  False        False  False  False
# 3                  False        False  False  False
# 4                  False        False  False  False
# ...                  ...          ...    ...    ...
# 2764173             True        False  False  False
# 2764174             True        False  False  False
# 2764175             True        False  False  False
# 2764176             True        False  False  False
# 2764177             True        False  False  False
#
#                            UTC_str       ROC    dSpeed    ASC
# 0        2018-02-03 12:23:52+00:00  0.000000  0.000000  False
# 1        2018-02-03 12:24:01+00:00  0.372942  0.444444   True
# 2        2018-02-03 12:24:10+00:00  0.125094  0.888889   True
# 3        2018-02-03 12:24:16+00:00  0.101132  0.666667   True
# 4        2018-02-03 12:24:22+00:00  0.358860 -0.666667   True
# ...                            ...       ...       ...    ...
# 2764173  2024-05-15 12:29:17+00:00  0.000000 -0.333333  False
# 2764174  2024-05-15 12:29:20+00:00  0.000000 -0.666667  False
# 2764175  2024-05-15 12:29:24+00:00  0.000000 -1.500000  False
# 2764176  2024-05-15 12:29:29+00:00  0.000000 -1.800000  False
# 2764177  2024-05-15 12:30:38+00:00  0.000000 -0.130435  False
#
# [2764178 rows x 19 columns]

# %%
features = d[['speed', 'altitude', 'ROC']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)

# %%
features_scaled
# Out:
# array([[-1.22338766, -0.79335971,  0.00807967],
#        [-1.10841619, -0.69231603,  0.17687697],
#        [-0.87847324, -0.65189856,  0.06469865],
#        ...,
#        [-2.80424543, -1.37941303,  0.00807967],
#        [-3.06293125, -1.37941303,  0.00807967],
#        [-3.32161707, -1.37941303,  0.00807967]])

# %%
x = pd.DataFrame(features_scaled)
x['flight_id'] = d['flight_id']
x_list = []
x.groupby('flight_id').apply(lambda x: x_list.append(x.values), include_groups=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
lengths = []
x.groupby('flight_id').apply(lambda x: lengths.append(len(x)), include_groups=False)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from hmmlearn import hmm

# %%
n_states = 3
model = hmm.GaussianHMM(n_components=n_states, n_iter=50, covariance_type='spherical')

# Fit the model
model.fit(features_scaled, lengths)
states = model.predict(features_scaled)

d['states'] = states

# %%
model.monitor_.converged
# Out:
# True

# %%
d.states.value_counts()
# Out:
# states
# 0    2273250
# 1     470425
# 2      20503
# Name: count, dtype: int64

# %%
d.groupby('states').agg({
    'speed': ['mean', 'std'],
    'altitude': ['mean', 'std'],
    'ROC': ['mean', 'std'],
    'ASC': ['mean', 'std'],
    'dSpeed': ['mean', 'std'],
})
# Out:
#              speed                altitude                    ROC             \
#               mean        std         mean          std      mean        std
# states
# 0       128.484039  16.457861  1884.370414  1143.308199 -0.012367   0.617231
# 1        52.111773  30.170302   646.535514   512.294714 -0.017559   0.374058
# 2       138.816563  29.079086  6299.455007  2234.317981 -0.632685  24.744917
#
#              ASC              dSpeed
#             mean       std      mean       std
# states
# 0       0.183729  0.387263 -0.023794  0.810455
# 1       0.182314  0.386103 -0.031099  0.757219
# 2       0.219139  0.413673  0.005359  0.726200

# %%
check_flight = np.random.choice(d.flight_id)
#check_flight= 686697156 #flyover västerås
color_map = {
    0: 'blue',
    1: 'red',
    2: 'green',
    3: 'orange',
    4: 'maroon',
    5: 'black'
}
m=airports_gdf.explore()

d[['geometry', 'flight_id', 'altitude', 'speed', 'ROC', 'dSpeed', 'states']].query(f"flight_id == {check_flight}").explore(m=m,color=d['states'].map(color_map))
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89243b0d96f8679e0f77c0603ee89ca0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89243b0d96f8679e0f77c0603ee89ca0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89243b0d96f8679e0f77c0603ee89ca0 = L.map(
#                 &quot;map_89243b0d96f8679e0f77c0603ee89ca0&quot;,
#                 {
#                     center: [61.42540989954378, 17.518324307296243],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_89243b0d96f8679e0f77c0603ee89ca0);
#
#
#
#
#
#             var tile_layer_6a8c6cdd5bee480c65b38f615e3bcdac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6a8c6cdd5bee480c65b38f615e3bcdac.addTo(map_89243b0d96f8679e0f77c0603ee89ca0);
#
#
#             map_89243b0d96f8679e0f77c0603ee89ca0.fitBounds(
#                 [[55.70286361361216, 11.841525845274306], [67.14795618547541, 23.19512276931818]],
#                 {}
#             );
#
#
#         function geo_json_f423f230f9255683a2a2abf9605abf01_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f423f230f9255683a2a2abf9605abf01_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f423f230f9255683a2a2abf9605abf01_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f423f230f9255683a2a2abf9605abf01_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f423f230f9255683a2a2abf9605abf01_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f423f230f9255683a2a2abf9605abf01.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f423f230f9255683a2a2abf9605abf01_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f423f230f9255683a2a2abf9605abf01 = L.geoJson(null, {
#                 onEachFeature: geo_json_f423f230f9255683a2a2abf9605abf01_onEachFeature,
#
#                 style: geo_json_f423f230f9255683a2a2abf9605abf01_styler,
#                 pointToLayer: geo_json_f423f230f9255683a2a2abf9605abf01_pointToLayer,
#         });
#
#         function geo_json_f423f230f9255683a2a2abf9605abf01_add (data) {
#             geo_json_f423f230f9255683a2a2abf9605abf01
#                 .addData(data);
#         }
#             geo_json_f423f230f9255683a2a2abf9605abf01_add({&quot;bbox&quot;: [11.841525845274306, 55.70286361361216, 23.19512276931818, 67.14795618547541], &quot;features&quot;: [{&quot;bbox&quot;: [17.622427294373324, 59.838356229161604, 17.658063938189187, 59.856287166941975], &

# %% [markdown]
# Conclusion: I can train a HMM to infer two states: flying and landing/takeoff. Problem is that it is mostly only using altitude/speed as features. If the take off is captured "late" it looks as if it is flying at level height. Also, it is very black boxy.
#
# Maybe the best is to do large bounding boxes and work with entries/exits.

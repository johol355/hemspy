# %%
import geopandas
import pandas as pd
import numpy as np
import os
import re

# %%
airports = pd.read_csv("/Users/JO/PhD/hemspy/data/helipad-data/raw-data/helipad-coordinates.csv", sep=";")

airports_gdf = geopandas.GeoDataFrame(airports, geometry=geopandas.points_from_xy(airports.longitude, airports.latitude), crs="EPSG:4326")
airports_gdf = airports_gdf.to_crs("EPSG:32634") #to metric coords
airports_gdf.geometry = airports_gdf.geometry.buffer(distance=airports.radius)
airports_gdf = airports_gdf.to_crs("EPSG:4326") #back to conventional

# %%
flights_path = '/Users/JO/PhD/hemspy/data/fr24-data/raw-data-unzipped-rearranged/flights'
flights_files = [f for f in os.listdir(flights_path) if f.endswith('.csv')]

flights_df_list, positions_df_list = [], []
for file in flights_files:
    flights_df_list.append(pd.read_csv(flights_path+'/'+file))

flights_df = pd.concat(flights_df_list, ignore_index=True)

flights_df['flight_id'] = flights_df['flight_id'].astype(int)

positions_path = '/Users/JO/PhD/hemspy/data/fr24-data/raw-data-unzipped-rearranged/positions'
positions_files = [os.path.join(positions_path, file) for file in os.listdir(positions_path) if file.endswith('.csv')]

# List to store DataFrames
positions_df_list = []

regex_pattern = r'_(.*?)\.'
regex = re.compile(regex_pattern)

# Iterate over each file
for file in positions_files:
    # Extract the flight_id from the file name
    flight_id_match = regex.search(os.path.basename(file))
    if flight_id_match:
        flight_id = flight_id_match.group(1)
        
        # Read the CSV file into a DataFrame
        df = pd.read_csv(file, usecols=['snapshot_id', 'altitude', 'latitude', 'longitude', 'speed'])
        
        # Add a column for flight_id
        df['flight_id'] = flight_id
        
        # Append the DataFrame to the list
        positions_df_list.append(df)

# Combine all DataFrames into a single DataFrame
positions_df = pd.concat(positions_df_list, ignore_index=True)

positions_df['flight_id'] = positions_df['flight_id'].astype(int)

d = pd.merge(positions_df, flights_df, on='flight_id', how='left')

d['UTC'] = pd.to_datetime(d['snapshot_id'], unit='s', utc=True)
d['date'] = d['UTC'].dt.date
d['year'] = d['UTC'].dt.year

# %% [markdown]
# ## Decrease size of dataset
# - Remove Stockholm
# - Remove Sjöfartsverket
# - Remove LN-XXX () and reg missing (subject to discussion)

# %%
d = d[d['equip'].isin(['A169', 'AS65', 'S76', 'EC45', 'A139'])]
d = d[~(d['reg'].isin(['SEJSR', 'SEJSP', 'SEJRH', 'SEJRI', 'SERJR', 'SEJRK', 'SEJRL', 'SEJRM', 'SEJRN']))]
d = d[~(d['reg'].str.startswith('LN') | pd.isna(d['reg']))]
d.head(3)
# Out:
#      snapshot_id  altitude  latitude  longitude  speed  flight_id aircraft_id  \
# 133   1486647941       175  59.32914   18.03285    106  208208779     4893263
# 134   1486647948       175  59.32440   18.02804    119  208208779     4893263
# 135   1486647976       174  59.32018   18.02427    123  208208779     4893263
#
#        reg equip callsign flight schd_from schd_to real_to reserved  \
# 133  SEJRO  EC45      NaN    NaN       BMA     NaN     NaN      NaN
# 134  SEJRO  EC45      NaN    NaN       BMA     NaN     NaN      NaN
# 135  SEJRO  EC45      NaN    NaN       BMA     NaN     NaN      NaN
#
#                           UTC        date  year
# 133 2017-02-09 13:45:41+00:00  2017-02-09  2017
# 134 2017-02-09 13:45:48+00:00  2017-02-09  2017
# 135 2017-02-09 13:46:16+00:00  2017-02-09  2017

# %%
d = geopandas.GeoDataFrame(d, geometry=geopandas.points_from_xy(d.longitude, d.latitude), crs="EPSG:4326")

# %%
d = geopandas.sjoin(d, airports_gdf, how="left", predicate="within")

# %%
d.drop(['index_right', 'ambulance_meetup', 'latitude_right', 'reserved', 'flight', 'callsign', 'longitude_right', 'radius', 'real_to', 'schd_from', 'schd_to', 'primary'], axis=1, inplace=True)
d
# Out:
#           snapshot_id  altitude  latitude_left  longitude_left  speed  \
# 133        1486647941       175       59.32914        18.03285    106
# 134        1486647948       175       59.32440        18.02804    119
# 135        1486647976       174       59.32018        18.02427    123
# 136        1486648031       175       59.30886        18.01559    123
# 137        1486648045       175       59.27356        17.97905    141
# ...               ...       ...            ...             ...    ...
# 43409707   1587302348      4700       58.60624        18.25411    150
# 43409708   1587302363      4725       58.60280        18.25499    150
# 43409709   1587302379      4725       58.59201        18.25795    150
# 43409710   1587302400      4700       58.58066        18.26129    150
# 43409711   1587302500      4700       58.56037        18.23603    152
#
#           flight_id aircraft_id    reg equip                       UTC  \
# 133       208208779     4893263  SEJRO  EC45 2017-02-09 13:45:41+00:00
# 134       208208779     4893263  SEJRO  EC45 2017-02-09 13:45:48+00:00
# 135       208208779     4893263  SEJRO  EC45 2017-02-09 13:46:16+00:00
# 136       208208779     4893263  SEJRO  EC45 2017-02-09 13:47:11+00:00
# 137       208208779     4893263  SEJRO  EC45 2017-02-09 13:47:25+00:00
# ...             ...         ...    ...   ...                       ...
# 43409707  610337411     4893263  SEJRO  EC45 2020-04-19 13:19:08+00:00
# 43409708  610337411     4893263  SEJRO  EC45 2020-04-19 13:19:23+00:00
# 43409709  610337411     4893263  SEJRO  EC45 2020-04-19 13:19:39+00:00
# 43409710  610337411     4893263  SEJRO  EC45 2020-04-19 13:20:00+00:00
# 43409711  610337411     4893263  SEJRO  EC45 2020-04-19 13:21:40+00:00
#
#                 date  year                   geometry hospital_name icao  \
# 133       2017-02-09  2017  POINT (18.03285 59.32914)           NaN  NaN
# 134       2017-02-09  2017  POINT (18.02804 59.32440)           NaN  NaN
# 135       2017-02-09  2017  POINT (18.02427 59.32018)           NaN  NaN
# 136       2017-02-09  2017  POINT (18.01559 59.30886)           NaN  NaN
# 137       2017-02-09  2017  POINT (17.97905 59.27356)           NaN  NaN
# ...              ...   ...                        ...           ...  ...
# 43409707  2020-04-19  2020  POINT (18.25411 58.60624)           NaN  NaN
# 43409708  2020-04-19  2020  POINT (18.25499 58.60280)           NaN  NaN
# 43409709  2020-04-19  2020  POINT (18.25795 58.59201)           NaN  NaN
# 43409710  2020-04-19  2020  POINT (18.26129 58.58066)           NaN  NaN
# 43409711  2020-04-19  2020  POINT (18.23603 58.56037)           NaN  NaN
#
#          helipad_location other_name
# 133                   NaN        NaN
# 134                   NaN        NaN
# 135                   NaN        NaN
# 136                   NaN        NaN
# 137                   NaN        NaN
# ...                   ...        ...
# 43409707              NaN        NaN
# 43409708              NaN        NaN
# 43409709              NaN        NaN
# 43409710              NaN        NaN
# 43409711              NaN        NaN
#
# [17005618 rows x 17 columns]

# %%
d_airport_only = d.dropna(subset="hospital_name")

# %%
d_airport_only
# Out:
#           snapshot_id  altitude  latitude_left  longitude_left  speed  \
# 264        1532272145       800       59.44423        13.35251     68
# 265        1532272154       725       59.44395        13.34744     51
# 266        1532272169       600       59.44331        13.34189     31
# 747        1638187315       800       59.84322        17.63800     36
# 748        1638187317       800       59.84346        17.63817     33
# ...               ...       ...            ...             ...    ...
# 43409505   1532755117         0       57.78199        11.86633      1
# 43409506   1532755138        50       57.78222        11.86707     20
# 43409507   1532755149       225       57.78380        11.87109     50
# 43409508   1532755157       275       57.78557        11.87485     69
# 43409509   1532755164       425       57.78683        11.87759     65
#
#           flight_id aircraft_id    reg equip                       UTC  \
# 264       490283653     4893443  SEJXC  EC45 2018-07-22 15:09:05+00:00
# 265       490283653     4893443  SEJXC  EC45 2018-07-22 15:09:14+00:00
# 266       490283653     4893443  SEJXC  EC45 2018-07-22 15:09:29+00:00
# 747       704972899     4893442  SEJXB  EC45 2021-11-29 12:01:55+00:00
# 748       704972899     4893442  SEJXB  EC45 2021-11-29 12:01:57+00:00
# ...             ...         ...    ...   ...                       ...
# 43409505  491457644     4893290  SEJSJ  A169 2018-07-28 05:18:37+00:00
# 43409506  491457644     4893290  SEJSJ  A169 2018-07-28 05:18:58+00:00
# 43409507  491457644     4893290  SEJSJ  A169 2018-07-28 05:19:09+00:00
# 43409508  491457644     4893290  SEJSJ  A169 2018-07-28 05:19:17+00:00
# 43409509  491457644     4893290  SEJSJ  A169 2018-07-28 05:19:24+00:00
#
#                 date  year                   geometry  \
# 264       2018-07-22  2018  POINT (13.35251 59.44423)
# 265       2018-07-22  2018  POINT (13.34744 59.44395)
# 266       2018-07-22  2018  POINT (13.34189 59.44331)
# 747       2021-11-29  2021  POINT (17.63800 59.84322)
# 748       2021-11-29  2021  POINT (17.63817 59.84346)
# ...              ...   ...                        ...
# 43409505  2018-07-28  2018  POINT (11.86633 57.78199)
# 43409506  2018-07-28  2018  POINT (11.86707 57.78222)
# 43409507  2018-07-28  2018  POINT (11.87109 57.78380)
# 43409508  2018-07-28  2018  POINT (11.87485 57.78557)
# 43409509  2018-07-28  2018  POINT (11.87759 57.78683)
#
#                               hospital_name   icao helipad_location  \
# 264                       Karlstads sjukhus   ESOK          airport
# 265                       Karlstads sjukhus   ESOK          airport
# 266                       Karlstads sjukhus   ESOK          airport
# 747                    Akademiska sjukhuset  ESHU          hospital
# 748                    Akademiska sjukhuset  ESHU          hospital
# ...                                     ...    ...              ...
# 43409505  Sahlgrenska universitetssjukhuset   ESGP          airport
# 43409506  Sahlgrenska universitetssjukhuset   ESGP          airport
# 43409507  Sahlgrenska universitetssjukhuset   ESGP          airport
# 43409508  Sahlgrenska universitetssjukhuset   ESGP          airport
# 43409509  Sahlgrenska universitetssjukhuset   ESGP          airport
#
#                     other_name
# 264         Karlstad flygplats
# 265         Karlstad flygplats
# 266         Karlstad flygplats
# 747       Akademiska sjukhuset
# 748       Akademiska sjukhuset
# ...                        ...
# 43409505        Säve flygplats
# 43409506        Säve flygplats
# 43409507        Säve flygplats
# 43409508        Säve flygplats
# 43409509        Säve flygplats
#
# [1319345 rows x 17 columns]

# %% [markdown]
# Next, sort by time

# %%
d_airport_only = d_airport_only.groupby('aircraft_id').apply(lambda x: x.sort_values('UTC'), include_groups=False)

# %%
d_airport_only.query("reg == 'SEJSN'").hospital_name.value_counts()
# Out:
# hospital_name
# Karolinska universitetssjukhuset, Solna    18644
# Visby lasarett                               672
# Akademiska sjukhuset                         559
# Länssjukhuset Ryhov                          505
# Länssjukhuset Kalmar                         447
# Sahlgrenska universitetssjukhuset            435
# Universitetssjukhuset i Linköping            422
# Kristianstads sjukhus                        390
# Nyköpings lasarett                           290
# Vrinnevisjukhuset                            282
# Sundsvalls sjukhus                           201
# Mälarsjukhuset                               199
# Karlstads sjukhus                            190
# Universitetssjukhuset Örebro                 166
# Bollnäs sjukhus                              150
# Hudiksvalls sjukhus                          143
# Hallands sjukhus Halmstad                    143
# Västerås lasarett                            129
# Falu lasarett                                125
# Huddinge sjukhus                             125
# Örnsköldsviks sjukhus                        108
# Universitetssjukhuset i Lund                  98
# Norrlands universitetssjukhus                 90
# Mora lasarett                                 90
# Torsby sjukhus                                66
# Gävle sjukhus                                 56
# Västerviks sjukhus                            55
# Östersunds sjukhus                            46
# Värnamo sjukhus                               40
# Kungälvs sjukhus                              38
# Skaraborgs sjukhus Skövde                     29
# Östra sjukhuset                               28
# Växjö lasarett                                24
# Sunderby sjukhus                              20
# Höglandssjukhuset                              2
# Enköpings lasarett                             2
# Lindesbergs lasarett                           1
# Name: count, dtype: int64

# %%
def process(x):
    # Keep only first and last row at a place
    shifted = x['other_name'].shift()
    start_seq = (x['other_name'] != shifted)
    end_seq = (x['other_name'] != x['other_name'].shift(-1))
    seq_indices = start_seq | end_seq
    new_x = x[seq_indices].reset_index(drop=True)
    # Check if moved
    new_x['moved'] = new_x['other_name'] != new_x['other_name'].shift(1)
    new_x['dwelled'] = ~ new_x['moved']
    # timetiff
    new_x["timediff"] = new_x.UTC - new_x.UTC.shift()
    new_x["timediff"] = new_x["timediff"].dt.total_seconds() / 60
    new_x['move_time'] = new_x['timediff'] * new_x['moved']
    new_x['move_time'] = np.where(new_x['move_time'] == 0, np.nan, new_x['move_time'])
    new_x['dwell_time'] = new_x['timediff'] * new_x['dwelled']
    new_x['dwell_time'] = np.where(new_x['dwell_time'] == 0, np.nan, new_x['dwell_time'])
    ## remove flyovers
    #new_x['dwell_time_flyover_removed'] = np.where(new_x['dwell_time'] > 5, new_x['dwell_time'], np.nan)
   # new_x['pair_id'] = np.arange(len(new_x)) // 2
   # new_x = new_x.groupby(['hospital_name', 'pair_id']).filter(
   # lambda x: x['dwell_time_flyover_removed'].sum() > 5).drop(columns='pair_id')
    ## clean up
   # new_x['timediff_new'] = new_x['UTC'] - new_x.shift(1)['UTC']
   # new_x["timediff_new"] = new_x["timediff_new"].dt.total_seconds() / 60

   # new_x['move_time_new'] = new_x['timediff_new'] * new_x['moved']
   # new_x['move_time'] = np.where(new_x['move_time_new'] == 0, np.nan, new_x['move_time_new'])
  #  new_x['dwell_time_new'] = new_x['timediff_new'] * new_x['dwelled']
  #  new_x['dwell_time'] = np.where(new_x['dwell_time_new'] == 0, np.nan, new_x['dwell_time_new'])

  #  new_x.drop(columns=['timediff', 'move_time_new', 'dwell_time_new', 'dwell_time_flyover_removed', 'timediff_new'], inplace=True)
    return new_x

# %%
df_processed = d_airport_only.groupby('aircraft_id').apply(process)

# Reset index if needed
df_processed = df_processed.reset_index(drop=True)

# %%
df_processed.query("reg == 'SEJSK'").tail(40)
# Out:
#        snapshot_id  altitude  latitude_left  longitude_left  speed  flight_id  \
# 30362   1715074631      1150       57.77284        11.88854     87  890888102
# 30363   1715076043       325       57.78937        11.87268     77  890891588
# 30364   1715081288       850       60.43373        15.48220     64  890891588
# 30365   1715082467      1375       60.44051        15.49432     87  890909870
# 30366   1715084950       175       61.73414        17.09513     33  890909870
# 30367   1715087116       225       61.72734        17.10581     66  890926570
# 30368   1715090042       225       59.89574        17.62235     69  890926570
# 30369   1715158899       100       59.88647        17.61601    102  891145155
# 30370   1715159609         0       59.63188        17.08592     87  891145155
# 30371   1715162091       150       59.62871        17.08649     84  891153337
# 30372   1715162782        50       59.84862        17.63443     50  891153337
# 30373   1715170434      1725       59.84788        17.63258     85  891178581
# 30374   1715174812         0       57.65406        18.30074     35  891178581
# 30375   1715177046         0       57.64897        18.29378     66  891203484
# 30376   1715179712        50       59.34691        18.02463     51  891206694
# 30377   1715181347       150       59.35423        18.03918     89  891225000
# 30378   1715182361         0       59.89934        17.61676     85  891225000
# 30379   1715327719       225       59.89851        17.61749     93  891686757
# 30380   1715335422       200       60.67786        17.12257     37  891700956
# 30381   1715338411       425       60.68275        17.11023     66  891718517
# 30382   1715339755       125       59.89853        17.60786     71  891718517
# 30383   1715429837       250       59.85104        17.64313     62  892016458
# 30384   1715431430       175       60.68179        17.11073     39  892016458
# 30385   1715435184       150       60.68015        17.12121     58  892040396
# 30386   1715436754       250       59.84309        17.64215     37  892040396
# 30387   1715437686         0       59.89233        17.60733      4  892051621
# 30388   1715605079       150       60.68061        17.10944     44  892527187
# 30389   1715607514       225       60.67916        17.12396     66  892538153
# 30390   1715608870       200       59.90076        17.60171     77  892538153
# 30391   1715677795       350       59.89080        17.59063     80  892745939
# 30392   1715681287       450       59.38046        13.47766     57  892745939
# 30393   1715684511       275       59.37314        13.47098     65  892762555
# 30394   1715688234      1300       59.35574        17.91797    138  892762555
# 30395   1715690509       375       59.35034        18.02463     74  892781286
# 30396   1715691453       425       59.89257        17.59044    113  892781286
# 30397   1715769836       375       59.89371        17.59167     82  893003809
# 30398   1715771793       700       60.60738        15.65356     66  893003809
# 30399   1715774068       475       60.60773        15.64557     10  893015657
# 30400   1715776115       100       59.90094        17.60632     80  893015657
# 30401   1715776169         0       59.89262        17.60739      9  893015657
#
#          reg equip                       UTC        date  ...  \
# 30362  SEJSK  A169 2024-05-07 09:37:11+00:00  2024-05-07  ...
# 30363  SEJSK  A169 2024-05-07 10:00:43+00:00  2024-05-07  ...
# 30364  SEJSK  A169 2024-05-07 11:28:08+00:00  2024-05-07  ...
# 30371    NaN         hospital                       Enköpings lasarett  False
# 30372  ESHU          hospital                     Akademiska sjukhuset   True
# 30373  ESHU          hospital                     Akademiska sjukhuset  False
# 30374   ESEV         hospital                           Visby lasarett   True
# 30375   ESEV         hospital                           Visby lasarett  False
# 30376   ESHK         hospital  Karolinska universitetssjukhuset, Solna   True
# 30377    NaN         hospital  Karolinska universitetssjukhuset, Solna  False
# 30378   ESCM          airport                           Ärna flygplats   True
# 30379   ESCM          airport                           Ärna flygplats  False
# 30380   ESJA         hospital                            Gävle sjukhus   True
# 30381   ESJA         hospital                            Gävle sjukhus  False
# 30382   ESCM          airport                           Ärna flygplats   True
# 30383  ESHU          hospital                     Akademiska sjukhuset  False
# 30384   ESJA         hospital                            Gävle sjukhus   True
# 30385   ESJA         hospital                            Gävle sjukhus  False
# 30386  ESHU          hospital                     Akademiska sjukhuset   True
# 30387   ESCM          airport                           Ärna flygplats  False
# 30388   ESJA         hospital                            Gävle sjukhus   True
# 30389   ESJA         hospital                            Gävle sjukhus  False
# 30390   ESCM          airport                           Ärna flygplats   True
# 30391   ESCM          airport                           Ärna flygplats  False
# 30392    NaN         hospital                        Karlstads sjukhus   True
# 30393    NaN         hospital                        Karlstads sjukhus  False
# 30394   ESSB          airport                                      BMA   True
# 30395   ESHK         hospital  Karolinska universitetssjukhuset, Solna  False
# 30396   ESCM          airport                           Ärna flygplats   True
# 30397   ESCM          airport                           Ärna flygplats  False
# 30398   ESEF         hospital                            Falu lasarett   True
# 30399   ESEF         hospital                            Falu lasarett  False
# 30400   ESCM          airport                           Ärna flygplats   True
# 30401   ESCM          airport                           Ärna flygplats  False
#
#        dwelled     timediff    move_time   dwell_time
# 30362    False     3.683333     3.683333          NaN
# 30363     True    23.533333          NaN    23.533333
# 30364    False    87.416667    87.416667          NaN
# 30365     True    19.650000          NaN    19.650000
# 30366    False    41.383333    41.383333          NaN
# 30367     True    36.100000          NaN    36.100000
# 30368    False    48.766667    48.766667          NaN
# 30369     True  1147.616667          NaN  1147.616667
# 30370    False    11.833333    11.833333          NaN
# 30371     True    41.366667          NaN    41.366667
# 30372    False    11.516667    11.516667          NaN
# 30373     True   127.533333          NaN   127.533333
# 30374    False    72.966667    72.966667          NaN
# 30375     True    37.233333          NaN    37.233333
# 30376    False    44.433333    44.433333          NaN
# 30377     True    27.250000          NaN    27.250000
# 30378    False    16.900000    16.900000          NaN
# 30379     True  2422.633333          NaN  2422.633333
# 30380    False   128.383333   128.383333          NaN
# 30381     True    49.816667          NaN    49.816667
# 30382    False    22.400000    22.400000          NaN
# 30383     True  1501.366667          NaN  1501.366667
# 30384    False    26.550000    26.550000          NaN
# 30385     True    62.566667          NaN    62.566667
# 30386    False    26.166667    26.166667          NaN
# 30387     True    15.533333          NaN    15.533333
# 30388    False  2789.883333  2789.883333          NaN
# 30389     True    40.583333          NaN    40.583333
# 30390    False    22.600000    22.600000          NaN
# 30391     True  1148.750000          NaN  1148.750000
# 30392    False    58.200000    58.200000          NaN
# 30393     True    53.733333          NaN    53.733333
# 30394    False    62.050000    62.050000          NaN
# 30395     True    37.916667          NaN    37.916667
# 30396    False    15.733333    15.733333          NaN
# 30397     True  1306.383333          NaN  1306.383333
# 30398    False    32.616667    32.616667          NaN
# 30399     True    37.916667          NaN    37.916667
# 30400    False    34.116667    34.116667          NaN
# 30401     True     0.900000          NaN     0.900000
#
# [40 rows x 21 columns]

# %%
def plot_flight(idx, dataset):
    fl = dataset[dataset["flight_id"] == idx]
    return fl.explore()

# %%
d.query("flight_id == 891718517").explore()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/IPython/core/formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/folium/folium.py:321, in Map._repr_html_(self, **kwargs)
#     319     self._parent = None
#     320 else:
# --> 321     out = self._parent._repr_html_(**kwargs)
#     322 return out
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/branca/element.py:369, in Figure._repr_html_(self, **kwargs)
#     367 def _repr_html_(self, **kwargs):
#     368     """Displays the Figure in a Jupyter notebook."""
# --> 369     html = escape(self.render(**kwargs))
#     370     if self.height is None:
#     371         iframe = (
#     372             '<div style="width:{width};">'
#     373             '<div style="position:relative;width:100%;height:0;padding-bottom:{ratio};">'  # noqa
#    (...)
#     379             "</div></div>"
#     380         ).format(html=html, width=self.width, ratio=self.ratio)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/branca/element.py:364, in Figure.render(self, **kwargs)
#     362 """Renders the HTML representation of the element."""
#     363 for name, child in self._children.items():
# --> 364     child.render(**kwargs)
#     365 return self._template.render(this=self, kwargs=kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/folium/folium.py:403, in Map.render(self, **kwargs)
#     376 figure.header.add_child(
#     377     Element(
#     378         "<style>html, body {"
#    (...)
#     386     name="css_style",
#     387 )
#     389 figure.header.add_child(
#     390     Element(
#     391         "<style>#map {"
#    (...)
#     400     name="map_style",
#     401 )
# --> 403 super().render(**kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/folium/elements.py:25, in JSCSSMixin.render(self, **kwargs)
#      22 for name, url in self.default_css:
#      23     figure.header.add_child(CssLink(url), name=name)
# ---> 25 super().render(**kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/branca/element.py:681, in MacroElement.render(self, **kwargs)
#     678     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     680 for name, element in self._children.items():
# --> 681     element.render(**kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/folium/features.py:831, in GeoJson.render(self, **kwargs)
#     829     if self.highlight:
#     830         self.highlight_map = mapper.get_highlight_map(self.highlight_function)
# --> 831 super().render()
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/folium/map.py:63, in Layer.render(self, **kwargs)
#      55 if self.show:
#      56     self.add_child(
#      57         ElementAddToElement(
#      58             element_name=self.get_name(),
#    (...)
#      61         name=self.get_name() + "_add",
#      62     )
# ---> 63 super().render(**kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/branca/element.py:678, in MacroElement.render(self, **kwargs)
#     676 script = self._template.module.__dict__.get("script", None)
#     677 if script is not None:
# --> 678     figure.script.add_child(Element(script(self, kwargs)), name=self.get_name())
#     680 for name, element in self._children.items():
#     681     element.render(**kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/jinja2/runtime.py:763, in Macro.__call__(self, *args, **kwargs)
#     757 elif len(args) > self._argument_count:
#     758     raise TypeError(
#     759         f"macro {self.name!r} takes not more than"
#     760         f" {len(self.arguments)} argument(s)"
#     761     )
# --> 763 return self._invoke(arguments, autoescape)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/jinja2/runtime.py:777, in Macro._invoke(self, arguments, autoescape)
#     774 if self._environment.is_async:
#     775     return self._async_invoke(arguments, autoescape)  # type: ignore
# --> 777 rv = self._func(*arguments)
#     779 if autoescape:
#     780     rv = Markup(rv)
#
# File <template>:264, in macro(l_1_this, l_1_kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/jinja2/filters.py:1702, in do_tojson(eval_ctx, value, indent)
#    1699     kwargs = kwargs.copy()
#    1700     kwargs["indent"] = indent
# -> 1702 return htmlsafe_json_dumps(value, dumps=dumps, **kwargs)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/site-packages/jinja2/utils.py:658, in htmlsafe_json_dumps(obj, dumps, **kwargs)
#     654 if dumps is None:
#     655     dumps = json.dumps
#     657 return markupsafe.Markup(
# --> 658     dumps(obj, **kwargs)
#     659     .replace("<", "\\u003c")
#     660     .replace(">", "\\u003e")
#     661     .replace("&", "\\u0026")
#     662     .replace("'", "\\u0027")
#     663 )
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/json/__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/json/encoder.py:200, in JSONEncoder.encode(self, o)
#     196         return encode_basestring(o)
#     197 # This doesn't pass the iterator directly to ''.join() because the
#     198 # exceptions aren't as detailed.  The list call should be roughly
#     199 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
#     202     chunks = list(chunks)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/json/encoder.py:258, in JSONEncoder.iterencode(self, o, _one_shot)
#     253 else:
#     254     _iterencode = _make_iterencode(
#     255         markers, self.default, _encoder, self.indent, floatstr,
#     256         self.key_separator, self.item_separator, self.sort_keys,
#     257         self.skipkeys, _one_shot)
# --> 258 return _iterencode(o, 0)
#
# File ~/miniforge3/envs/epidemiology-pyenv/lib/python3.11/json/encoder.py:180, in JSONEncoder.default(self, o)
#     161 def default(self, o):
#     162     """Implement this method in a subclass such that it returns
#     163     a serializable object for ``o``, or calls the base implementation
#     164     (to raise a ``TypeError``).
#    (...)
#     178
#     179     """
# --> 180     raise TypeError(f'Object of type {o.__class__.__name__} '
#     181                     f'is not JSON serializable')
#
# TypeError: Object of type Timestamp is not JSON serializable

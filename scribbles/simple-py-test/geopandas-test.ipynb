# %%
import geopandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load sample flights
# First, two well behaved flights from a sending center to a receiving center
well_behaved_a = "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/DFL5710_35200a2b.csv"
well_behaved_b = "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/SWV5960_3526909c.csv"
# Next, a bunch of trickier flights
tricky_a =  "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/SWV5850_345f09a8.csv"
tricky_b_part_1 =  "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/SWV5850_34bac707.csv"
tricky_b_part_2 = "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/SWV5850_34bad6ce.csv"
tricky_c_part_1 = "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/DFL5940_34f7c0ea.csv"
tricky_c_part_2 = "/Users/JO/PhD/hemspy/data/sample-data/hems-examples/DFL5940_34f82b91.csv"

# Define location of some helipads at sending and receving hospitals
airports_dict = {
"hudiksvall": (61.7304, 17.0996), ## sending hospital
"akademiska": (59.8472, 17.6402), ## this is a receiving center
"arna": (59.8920, 17.6066), ## this is an aiport
"karolinska": (59.3493, 18.0319), ## this is a receiving center
"torsby": (60.1367, 12.9974), ## sending hospital
"orebro": (59.2748, 15.2288), ## this is a receiving center
"orebro airport": (59.22781316906504, 15.03996851019997),
"sunderbyn": (65.67241724908286, 21.935790886203712), ## sending hospital
"kalix": (65.85566778285997, 23.171565979697636), ## sending hospital
"umea": (63.81735866549869, 20.298453547845288), ## sending hospital
"falun": (60.60763426546648, 15.645371300139645), ## sending hospital
"gallivare": (67.13107231727535, 20.682936085413385), ## sending hospital
"solleftea": (63.17472146034687, 17.2314090459214), ## sending hospital
"ostersund": (63.191907852275854, 14.63084350106227),
"karlstad sjukhus": (59.37630930990766, 13.47608275695035),
"karlstad flp": (59.445175903584, 13.337658312889811),
"västerås lasarett": (59.61580394969142, 16.582052775226977)
}

airports = pd.DataFrame(airports_dict).T.reset_index().rename(columns={"index": "airport", 0: "latitude", 1: "longitude"})

# %%
## make geometries
airports_gdf = geopandas.GeoDataFrame(airports, geometry=geopandas.points_from_xy(airports.longitude, airports.latitude), crs="EPSG:4326")
airports_gdf = airports_gdf.to_crs("EPSG:32634") #to metric coords
airports_gdf.geometry = airports_gdf.geometry.buffer(distance=1100)
airports_gdf = airports_gdf.to_crs("EPSG:4326") #back to conventional

# %%
def create_flight_df(csv_path, airports):
    flight = pd.read_csv(csv_path)
    flight[['latitude', 'longitude']] = flight['Position'].str.split(',', expand=True)
    flight = geopandas.GeoDataFrame(flight, geometry=geopandas.points_from_xy(flight.longitude, flight.latitude), crs="EPSG:4326")
    flight = geopandas.sjoin(flight, airports, how="left", predicate="within")
    flight.drop(['Position', 'index_right', 'latitude_left', 'latitude_right', 'latitude_right', 'longitude_right', 'longitude_left'], axis=1, inplace=True)
    return flight

# %%
def plot_flight_df(flight_df, airports):
    m = flight_df.explore()
    return airports.explore(m=m, color='maroon', style_kwds={'fillOpacity': 0.1, 'weight':2})

# %% [markdown]
# ### A well behaved flight

# %%
df1 = create_flight_df(well_behaved_a, airports_gdf)

# %%
plot_flight_df(df1, airports_gdf)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ebbed7ac3e8bdfb32d2ce2126cab206 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ebbed7ac3e8bdfb32d2ce2126cab206&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ebbed7ac3e8bdfb32d2ce2126cab206 = L.map(
#                 &quot;map_5ebbed7ac3e8bdfb32d2ce2126cab206&quot;,
#                 {
#                     center: [60.536484, 17.565704],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5ebbed7ac3e8bdfb32d2ce2126cab206);
#
#
#
#
#
#             var tile_layer_c74b667a701ef2c5dddca840f1b91c70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c74b667a701ef2c5dddca840f1b91c70.addTo(map_5ebbed7ac3e8bdfb32d2ce2126cab206);
#
#
#             map_5ebbed7ac3e8bdfb32d2ce2126cab206.fitBounds(
#                 [[59.342373, 17.099813], [61.730595, 18.031595]],
#                 {}
#             );
#
#
#         function geo_json_45cb9449cb9804012c228ce6137371fd_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_45cb9449cb9804012c228ce6137371fd_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_45cb9449cb9804012c228ce6137371fd_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_45cb9449cb9804012c228ce6137371fd_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_45cb9449cb9804012c228ce6137371fd_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_45cb9449cb9804012c228ce6137371fd.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_45cb9449cb9804012c228ce6137371fd_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_45cb9449cb9804012c228ce6137371fd = L.geoJson(null, {
#                 onEachFeature: geo_json_45cb9449cb9804012c228ce6137371fd_onEachFeature,
#
#                 style: geo_json_45cb9449cb9804012c228ce6137371fd_styler,
#                 pointToLayer: geo_json_45cb9449cb9804012c228ce6137371fd_pointToLayer,
#         });
#
#         function geo_json_45cb9449cb9804012c228ce6137371fd_add (data) {
#             geo_json_45cb9449cb9804012c228ce6137371fd
#                 .addData(data);
#         }
#             geo_json_45cb9449cb9804012c228ce6137371fd_add({&quot;bbox&quot;: [17.099813, 59.342373, 18.031595, 61.730595], &quot;features&quot;: [{&quot;bbox&quot;: [17.099813, 61.730595, 17.099813, 61.730595], &quot;geometry&quot;: {&quot;coordinates&quot;: [17.099813, 61.730595], &quot;type&quot;: &quot;Point&quot;}, &quot;id&q

# %% [markdown]
# ### A trickier flight

# %%
df2 = create_flight_df(tricky_a, airports_gdf)

# %%
plot_flight_df(df2, airports_gdf)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_363763f90f320a6ad7614c7b7acb17a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_363763f90f320a6ad7614c7b7acb17a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_363763f90f320a6ad7614c7b7acb17a6 = L.map(
#                 &quot;map_363763f90f320a6ad7614c7b7acb17a6&quot;,
#                 {
#                     center: [64.8926735, 21.7391675],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_363763f90f320a6ad7614c7b7acb17a6);
#
#
#
#
#
#             var tile_layer_fa90f5e4fe219a884fc0229ea477c1f6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fa90f5e4fe219a884fc0229ea477c1f6.addTo(map_363763f90f320a6ad7614c7b7acb17a6);
#
#
#             map_363763f90f320a6ad7614c7b7acb17a6.fitBounds(
#                 [[63.817291, 20.298615], [65.968056, 23.17972]],
#                 {}
#             );
#
#
#         function geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7 = L.geoJson(null, {
#                 onEachFeature: geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_onEachFeature,
#
#                 style: geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_styler,
#                 pointToLayer: geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_pointToLayer,
#         });
#
#         function geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_add (data) {
#             geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7
#                 .addData(data);
#         }
#             geo_json_fc072a98d1bc26aebcad3a2fdf3b90e7_add({&quot;bbox&quot;: [20.298615, 63.817291, 23.17972, 65.968056], &quot;features&quot;: [{&quot;bbox&quot;: [21.681639, 65.968056, 21.681639, 65.968056], &quot;geometry&quot;: {&quot;coordinates&quot;: [21.681639, 65.968056], &quot;type&quot;: &quot;Point&quot;}, &quot;id&q

# %% [markdown]
# ### Working with merged flights and preprocessing

# %% [markdown]
# - Merge flights
# - Plot
# - Remove rows "between" airports
# - Remove as many row as possible "at" airports
# - Remove "fly-overs"
# - Calculate times

# %% [markdown]
# First, import and merge df:

# %%
import os
# Define the folder path containing the CSV files
folder_path = '/Users/JO/PhD/hemspy/data/sample-data/karlstad-examples'

# Get a list of all CSV files in the folder and read them into DataFrames
data_frames = [pd.read_csv(os.path.join(folder_path, f)) for f in os.listdir(folder_path) if f.endswith('.csv')]

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(data_frames, ignore_index=True)

# %% [markdown]
# Create and plot flight:

# %%
def create_flight_df(df, airports):
    flight = df.copy()
    flight[['latitude', 'longitude']] = flight['Position'].str.split(',', expand=True)
    flight = geopandas.GeoDataFrame(flight, geometry=geopandas.points_from_xy(flight.longitude, flight.latitude), crs="EPSG:4326")
    flight = geopandas.sjoin(flight, airports, how="left", predicate="within")
    flight.drop(['Position', 'index_right', 'latitude_left', 'latitude_right', 'latitude_right', 'longitude_right', 'longitude_left'], axis=1, inplace=True)
    return flight

# %%
k = create_flight_df(combined_df, airports_gdf)

# %%
plot_flight_df(k, airports_gdf)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f89a94988dfba83ddfc69812a1047de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f89a94988dfba83ddfc69812a1047de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f89a94988dfba83ddfc69812a1047de = L.map(
#                 &quot;map_5f89a94988dfba83ddfc69812a1047de&quot;,
#                 {
#                     center: [59.689045, 14.888855],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5f89a94988dfba83ddfc69812a1047de);
#
#
#
#
#
#             var tile_layer_db783a1b183bbc6127be6bf69b280069 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_db783a1b183bbc6127be6bf69b280069.addTo(map_5f89a94988dfba83ddfc69812a1047de);
#
#
#             map_5f89a94988dfba83ddfc69812a1047de.fitBounds(
#                 [[59.21933, 12.134399], [60.15876, 17.643311]],
#                 {}
#             );
#
#
#         function geo_json_94004e0b598ed3e49d5c161db10b5fff_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_94004e0b598ed3e49d5c161db10b5fff_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_94004e0b598ed3e49d5c161db10b5fff_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_94004e0b598ed3e49d5c161db10b5fff_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_94004e0b598ed3e49d5c161db10b5fff_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_94004e0b598ed3e49d5c161db10b5fff.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_94004e0b598ed3e49d5c161db10b5fff_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_94004e0b598ed3e49d5c161db10b5fff = L.geoJson(null, {
#                 onEachFeature: geo_json_94004e0b598ed3e49d5c161db10b5fff_onEachFeature,
#
#                 style: geo_json_94004e0b598ed3e49d5c161db10b5fff_styler,
#                 pointToLayer: geo_json_94004e0b598ed3e49d5c161db10b5fff_pointToLayer,
#         });
#
#         function geo_json_94004e0b598ed3e49d5c161db10b5fff_add (data) {
#             geo_json_94004e0b598ed3e49d5c161db10b5fff
#                 .addData(data);
#         }
#             geo_json_94004e0b598ed3e49d5c161db10b5fff_add({&quot;bbox&quot;: [12.134399, 59.21933, 17.643311, 60.15876], &quot;features&quot;: [{&quot;bbox&quot;: [12.997218, 60.136368, 12.997218, 60.136368], &quot;geometry&quot;: {&quot;coordinates&quot;: [12.997218, 60.136368], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;

# %% [markdown]
# As you can see, there is a fly-over (aircraft flying over a "landing zone" at Örebro. Even if the landing zone had been smallar (100-200 m) it would still be within it.

# %% [markdown]
# Let's remove all rows "between" landing zones:

# %%
k.sort_values(by="Timestamp", inplace=True)
k_airport_only = k.dropna(subset="airport")

# %% [markdown]
# Next, keep only the first and last row when an aircraft is within a landing zone. This will be done by shifting columns up and down an compare values in column airport. This allows for sorting rows without a for loop.

# %%
# Sample data

# Shift the column to create a comparison for finding sequence boundaries
shifted = k_airport_only['airport'].shift()

# Identify the start of each sequence
start_sequence = (k_airport_only['airport'] != shifted)

# Identify the end of each sequence
end_sequence = (k_airport_only['airport'] != k_airport_only['airport'].shift(-1))

# Combine the indices of the start and end of each sequence
sequence_indices = start_sequence | end_sequence

# Use the combined indices to filter the DataFrame
new_k = k_airport_only[sequence_indices].reset_index(drop=True)

new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 0   1714390457  2024-04-29T11:34:17Z  SWV5960       400     65        276
# 1   1714390485  2024-04-29T11:34:45Z  SWV5960       775     76        348
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 6   1714404013  2024-04-29T15:20:13Z  SWV5960      1800    106        244
# 7   1714404049  2024-04-29T15:20:49Z  SWV5960      1800    105        244
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport
# 0   POINT (13.33136 59.44318)    karlstad flp
# 1   POINT (13.32414 59.45121)    karlstad flp
# 2   POINT (13.00722 60.12868)          torsby
# 3   POINT (13.00369 60.12790)          torsby
# 4   POINT (17.63800 59.85654)      akademiska
# 5   POINT (17.64304 59.83841)      akademiska
# 6   POINT (15.24362 59.27774)          orebro
# 7   POINT (15.21228 59.27012)          orebro
# 8   POINT (15.04349 59.23727)  orebro airport
# 9   POINT (15.03024 59.21943)  orebro airport
# 10  POINT (13.34498 59.45284)    karlstad flp
# 11  POINT (13.34280 59.45073)    karlstad flp

# %% [markdown]
# Next, we will define if each row is "associated" with the aircraft moving in to the zone or "dwelling" (but potentially moving) in it. This is to mark the rows for "entering" or "leaving a zone" (could be better names for the columns actually...)

# %%
new_k['moved'] = new_k['airport'] != new_k['airport'].shift(1)
new_k['dwelled'] = ~ new_k['moved']
new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 0   1714390457  2024-04-29T11:34:17Z  SWV5960       400     65        276
# 1   1714390485  2024-04-29T11:34:45Z  SWV5960       775     76        348
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 6   1714404013  2024-04-29T15:20:13Z  SWV5960      1800    106        244
# 7   1714404049  2024-04-29T15:20:49Z  SWV5960      1800    105        244
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport  moved  dwelled
# 0   POINT (13.33136 59.44318)    karlstad flp   True    False
# 1   POINT (13.32414 59.45121)    karlstad flp  False     True
# 2   POINT (13.00722 60.12868)          torsby   True    False
# 3   POINT (13.00369 60.12790)          torsby  False     True
# 4   POINT (17.63800 59.85654)      akademiska   True    False
# 5   POINT (17.64304 59.83841)      akademiska  False     True
# 6   POINT (15.24362 59.27774)          orebro   True    False
# 7   POINT (15.21228 59.27012)          orebro  False     True
# 8   POINT (15.04349 59.23727)  orebro airport   True    False
# 9   POINT (15.03024 59.21943)  orebro airport  False     True
# 10  POINT (13.34498 59.45284)    karlstad flp   True    False
# 11  POINT (13.34280 59.45073)    karlstad flp  False     True

# %% [markdown]
# Calculate the time differences between the row and the preceeding row. In case it is a "moved" row, this would be "flight time". In case it is a "dwelled" row, this would be the time spent in the zone.

# %%
# calc timediff
new_k["timediff_minutes"] = new_k.Timestamp - new_k.Timestamp.shift()
new_k["timediff_minutes"] = np.round(new_k.timediff_minutes/60, 0)

# %%
new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 0   1714390457  2024-04-29T11:34:17Z  SWV5960       400     65        276
# 1   1714390485  2024-04-29T11:34:45Z  SWV5960       775     76        348
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 6   1714404013  2024-04-29T15:20:13Z  SWV5960      1800    106        244
# 7   1714404049  2024-04-29T15:20:49Z  SWV5960      1800    105        244
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport  moved  dwelled  \
# 0   POINT (13.33136 59.44318)    karlstad flp   True    False
# 1   POINT (13.32414 59.45121)    karlstad flp  False     True
# 2   POINT (13.00722 60.12868)          torsby   True    False
# 3   POINT (13.00369 60.12790)          torsby  False     True
# 4   POINT (17.63800 59.85654)      akademiska   True    False
# 5   POINT (17.64304 59.83841)      akademiska  False     True
# 6   POINT (15.24362 59.27774)          orebro   True    False
# 7   POINT (15.21228 59.27012)          orebro  False     True
# 8   POINT (15.04349 59.23727)  orebro airport   True    False
# 9   POINT (15.03024 59.21943)  orebro airport  False     True
# 10  POINT (13.34498 59.45284)    karlstad flp   True    False
# 11  POINT (13.34280 59.45073)    karlstad flp  False     True
#
#     timediff_minutes
# 0                NaN
# 1                0.0
# 2               20.0
# 3               50.0
# 4               61.0
# 5               49.0
# 6               45.0
# 7                1.0
# 8                4.0
# 9               32.0
# 10              31.0
# 11            2467.0

# %% [markdown]
# We can create new columns with "move time" and "dwell time" as well:

# %%
new_k['move_time'] = new_k['timediff_minutes'] * new_k['moved']
new_k['move_time'] = np.where(new_k['move_time'] == 0, np.nan, new_k['move_time'])
new_k['dwell_time'] = new_k['timediff_minutes'] * new_k['dwelled']
new_k['dwell_time'] = np.where(new_k['dwell_time'] == 0, np.nan, new_k['dwell_time'])

new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 0   1714390457  2024-04-29T11:34:17Z  SWV5960       400     65        276
# 1   1714390485  2024-04-29T11:34:45Z  SWV5960       775     76        348
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 6   1714404013  2024-04-29T15:20:13Z  SWV5960      1800    106        244
# 7   1714404049  2024-04-29T15:20:49Z  SWV5960      1800    105        244
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport  moved  dwelled  \
# 0   POINT (13.33136 59.44318)    karlstad flp   True    False
# 1   POINT (13.32414 59.45121)    karlstad flp  False     True
# 2   POINT (13.00722 60.12868)          torsby   True    False
# 3   POINT (13.00369 60.12790)          torsby  False     True
# 4   POINT (17.63800 59.85654)      akademiska   True    False
# 5   POINT (17.64304 59.83841)      akademiska  False     True
# 6   POINT (15.24362 59.27774)          orebro   True    False
# 7   POINT (15.21228 59.27012)          orebro  False     True
# 8   POINT (15.04349 59.23727)  orebro airport   True    False
# 9   POINT (15.03024 59.21943)  orebro airport  False     True
# 10  POINT (13.34498 59.45284)    karlstad flp   True    False
# 11  POINT (13.34280 59.45073)    karlstad flp  False     True
#
#     timediff_minutes  move_time  dwell_time
# 0                NaN        NaN         NaN
# 1                0.0        NaN         NaN
# 2               20.0       20.0         NaN
# 3               50.0        NaN        50.0
# 4               61.0       61.0         NaN
# 5               49.0        NaN        49.0
# 6               45.0       45.0         NaN
# 7                1.0        NaN         1.0
# 8                4.0        4.0         NaN
# 9               32.0        NaN        32.0
# 10              31.0       31.0         NaN
# 11            2467.0        NaN      2467.0

# %% [markdown]
# Next, let's filter out visits to landing zones that are probably fly-overs. Even a slow moving aircraft at 150 km/h is travelling at 41.6 m/s, meaning that it would take <1 minute to travel 2 km. In the case of the fly-over at Örebro, the time is rounded down to 0 minutes. Allowing for some wiggle room, let's remove all visits < 5 minutes. Of course, the Örebro thing dissapears.

# %%
new_k['dwell_time_flyover_removed'] = np.where(new_k['dwell_time'] > 5, new_k['dwell_time'], np.nan)

# %%
new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 0   1714390457  2024-04-29T11:34:17Z  SWV5960       400     65        276
# 1   1714390485  2024-04-29T11:34:45Z  SWV5960       775     76        348
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 6   1714404013  2024-04-29T15:20:13Z  SWV5960      1800    106        244
# 7   1714404049  2024-04-29T15:20:49Z  SWV5960      1800    105        244
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport  moved  dwelled  \
# 0   POINT (13.33136 59.44318)    karlstad flp   True    False
# 1   POINT (13.32414 59.45121)    karlstad flp  False     True
# 2   POINT (13.00722 60.12868)          torsby   True    False
# 3   POINT (13.00369 60.12790)          torsby  False     True
# 4   POINT (17.63800 59.85654)      akademiska   True    False
# 5   POINT (17.64304 59.83841)      akademiska  False     True
# 6   POINT (15.24362 59.27774)          orebro   True    False
# 7   POINT (15.21228 59.27012)          orebro  False     True
# 8   POINT (15.04349 59.23727)  orebro airport   True    False
# 9   POINT (15.03024 59.21943)  orebro airport  False     True
# 10  POINT (13.34498 59.45284)    karlstad flp   True    False
# 11  POINT (13.34280 59.45073)    karlstad flp  False     True
#
#     timediff_minutes  move_time  dwell_time  dwell_time_flyover_removed
# 0                NaN        NaN         NaN                         NaN
# 1                0.0        NaN         NaN                         NaN
# 2               20.0       20.0         NaN                         NaN
# 3               50.0        NaN        50.0                        50.0
# 4               61.0       61.0         NaN                         NaN
# 5               49.0        NaN        49.0                        49.0
# 6               45.0       45.0         NaN                         NaN
# 7                1.0        NaN         1.0                         NaN
# 8                4.0        4.0         NaN                         NaN
# 9               32.0        NaN        32.0                        32.0
# 10              31.0       31.0         NaN                         NaN
# 11            2467.0        NaN      2467.0                      2467.0

# %% [markdown]
# Next, let's assign id_numbers to the "pairs" defining the landing zone visits. This will allow for grouping by this ID and removing those with dwell times < 5 minutes>

# %%
new_k['pair_id'] = np.arange(len(new_k)) // 2
new_k = new_k.groupby(['airport', 'pair_id']).filter(
    lambda x: x['dwell_time_flyover_removed'].sum() > 5).drop(columns='pair_id')

# %%
new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport  moved  dwelled  \
# 2   POINT (13.00722 60.12868)          torsby   True    False
# 3   POINT (13.00369 60.12790)          torsby  False     True
# 4   POINT (17.63800 59.85654)      akademiska   True    False
# 5   POINT (17.64304 59.83841)      akademiska  False     True
# 8   POINT (15.04349 59.23727)  orebro airport   True    False
# 9   POINT (15.03024 59.21943)  orebro airport  False     True
# 10  POINT (13.34498 59.45284)    karlstad flp   True    False
# 11  POINT (13.34280 59.45073)    karlstad flp  False     True
#
#     timediff_minutes  move_time  dwell_time  dwell_time_flyover_removed
# 2               20.0       20.0         NaN                         NaN
# 3               50.0        NaN        50.0                        50.0
# 4               61.0       61.0         NaN                         NaN
# 5               49.0        NaN        49.0                        49.0
# 8                4.0        4.0         NaN                         NaN
# 9               32.0        NaN        32.0                        32.0
# 10              31.0       31.0         NaN                         NaN
# 11            2467.0        NaN      2467.0                      2467.0

# %% [markdown]
# After the removal of rows, we need to recalculate travel times:

# %%
new_k['timediff_minutes_new'] = new_k['Timestamp'] - new_k.shift(1)['Timestamp']
new_k["timediff_minutes_new"] = np.round(new_k.timediff_minutes_new/60, 0)

new_k['move_time_new'] = new_k['timediff_minutes_new'] * new_k['moved']
new_k['move_time'] = np.where(new_k['move_time_new'] == 0, np.nan, new_k['move_time_new'])
new_k['dwell_time_new'] = new_k['timediff_minutes_new'] * new_k['dwelled']
new_k['dwell_time'] = np.where(new_k['dwell_time_new'] == 0, np.nan, new_k['dwell_time_new'])

# %%
new_k.drop(columns=['timediff_minutes', 'move_time_new', 'dwell_time_new', 'dwell_time_flyover_removed', 'timediff_minutes_new'], inplace=True)

# %% [markdown]
# And finally:

# %%
new_k
# Out:
#      Timestamp                   UTC Callsign  Altitude  Speed  Direction  \
# 2   1714391666  2024-04-29T11:54:26Z  SWV5960       650     83        346
# 3   1714394667  2024-04-29T12:44:27Z  SWV5960       725     68        156
# 4   1714398356  2024-04-29T13:45:56Z  SWV5960       575     61        127
# 5   1714401289  2024-04-29T14:34:49Z  SWV5960       475     75        192
# 8   1714404260  2024-04-29T15:24:20Z  SWV5960       150     58        192
# 9   1714406151  2024-04-29T15:55:51Z  SWV5960       250     60        278
# 10  1714408012  2024-04-29T16:26:52Z  SWV5960       200     64        203
# 11  1714556048  2024-05-01T09:34:08Z  SWV5960        50     40        204
#
#                      geometry         airport  moved  dwelled  move_time  \
# 2   POINT (13.00722 60.12868)          torsby   True    False        NaN
# 3   POINT (13.00369 60.12790)          torsby  False     True        NaN
# 4   POINT (17.63800 59.85654)      akademiska   True    False       61.0
# 5   POINT (17.64304 59.83841)      akademiska  False     True        NaN
# 8   POINT (15.04349 59.23727)  orebro airport   True    False       50.0
# 9   POINT (15.03024 59.21943)  orebro airport  False     True        NaN
# 10  POINT (13.34498 59.45284)    karlstad flp   True    False       31.0
# 11  POINT (13.34280 59.45073)    karlstad flp  False     True        NaN
#
#     dwell_time
# 2          NaN
# 3         50.0
# 4          NaN
# 5         49.0
# 8          NaN
# 9         32.0
# 10         NaN
# 11      2467.0

# %% [markdown]
# ## Ideas/insigths:
#
# * This describes the actually events in a reasonable manner.
#
# * Idea: check relevant helipads for ads-b coverage, select different radiuses based on coverage (smaller if better coverage). This could potentially be done by plotting all flights and guesstimate a reasonable radius.
#
# * Insight: in matching flights to patients, it could be reasonable to add a mechanism making sure that a flight should note take more than 0.0.5-3 h (depending on distance) in order to protect against A->(C)->B flights.
#
# * a less involved approach would be to just calculate inferred times and describe the variance. Hopefully there is little variation. Throw away all +/- x sd?
#
# *
